# %%
# 1. operators
#1.Write a Python program to take two numbers as input and print their sum, difference, product, and quotient. 
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Quotient:", a / b)
# Out:
# Enter first number:  55
# Enter second number:  69
# Sum: 124.0
# Difference: -14.0
# Product: 3795.0
# Quotient: 0.7971014492753623

# %%
# 2.	Write a Python program to calculate the area of a rectangle using length and breadth. 

length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth
print("Area of rectangle:", area)
# Out:
# Enter length:  4
# Enter breadth:  2
# Area of rectangle: 8.0

# %%
#3.	Write a Python program to find the remainder when one number is divided by another. 
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Remainder:", a % b)
# Out:
# Enter first number:  6
# Enter second number:  2
# Remainder: 0

# %%
#4.	Write a Python program to swap two numbers using a temporary variable.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

temp = a
a = b
b = temp

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number:  4
# Enter second number:  6
# After swapping:
# a = 6
# b = 4

# %%
#5.	Write a Python program to calculate Simple Interest using the formula:
# Simple Interest = (P × R × T) / 100


p = float(input("Enter principal: "))
r = float(input("Enter rate: "))
t = float(input("Enter time: "))

si = (p * r * t) / 100
print("Simple Interest:", si)
# Out:
# Enter principal:  9
# Enter rate:  2
# Enter time:  2
# Simple Interest: 0.36
